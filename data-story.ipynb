# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pylab import *

red_wine = pd.read_csv('https://query.data.world/s/rrj4d2f6sj2apz4x7sozpd6epmrsiy')
white_wine = pd.read_csv('https://query.data.world/s/brho7trfnuy4iz2nxraqzsfwvgek5b')

white_wine_9 = white_wine.loc[ white_wine['quality'] == 9 ]
white_wine_8 = white_wine.loc[ white_wine['quality'] == 8 ]
white_wine_7 = white_wine.loc[ white_wine['quality'] == 7 ]
white_wine_6 = white_wine.loc[ white_wine['quality'] == 6 ]
white_wine_5 = white_wine.loc[ white_wine['quality'] == 5 ]
white_wine_4 = white_wine.loc[ white_wine['quality'] == 4 ]
white_wine_3 = white_wine.loc[ white_wine['quality'] == 3 ]


red_wine_8 = red_wine.loc[ red_wine['quality'] == 8 ]
red_wine_7 = red_wine.loc[ red_wine['quality'] == 7 ]
red_wine_6 = red_wine.loc[ red_wine['quality'] == 6 ]
red_wine_5 = red_wine.loc[ red_wine['quality'] == 5 ]
red_wine_4 = red_wine.loc[ red_wine['quality'] == 4 ]
red_wine_3 = red_wine.loc[ red_wine['quality'] == 3 ]

# %%
#Build frequency histograms for each rating of each feature
fig, axes = plt.subplots(nrows=4, ncols=2)

print('Fixed Acidity')

subplot(4, 2, 1)
plt.title('Fixed Acidity_9')
white_wine_9['fixed acidity'].hist(range=[4,11])

subplot(4, 2, 2)
plt.title('Fixed Acidity_8')
white_wine_8['fixed acidity'].hist(range=[4,11])

subplot(4, 2, 3)
plt.title('Fixed Acidity_7')
white_wine_7['fixed acidity'].hist(range=[4,11])

subplot(4, 2, 4)
plt.title('Fixed Acidity_6')
white_wine_6['fixed acidity'].hist(range=[4,11])

subplot(4, 2, 5)
plt.title('Fixed Acidity_5')
white_wine_5['fixed acidity'].hist(range=[4,11])

subplot(4, 2, 6)
plt.title('Fixed Acidity_4')
white_wine_4['fixed acidity'].hist(range=[4,11])

subplot(4, 2, 7)
plt.title('Fixed Acidity_3')
white_wine_3['fixed acidity'].hist(range=[4,11])


plt.tight_layout()
# Out:
# Fixed Acidity

# %% [markdown]
# There doesn't seem to be any 'quality' bias based on 'Fixed Acidity'

# %%
#Build frequency histograms for each rating of each feature
fig, axes = plt.subplots(nrows=4, ncols=2)

print('Volatile Acidity')

subplot(4, 2, 1)
plt.title('Volatile Acidity_9')
white_wine_9['volatile acidity'].hist(range=[0.1,0.75])

subplot(4, 2, 2)
plt.title('Volatile Acidity_8')
white_wine_8['volatile acidity'].hist(range=[0.1,0.75])

subplot(4, 2, 3)
plt.title('Volatile Acidity_7')
white_wine_7['volatile acidity'].hist(range=[0.1,0.75])

subplot(4, 2, 4)
plt.title('Volatile Acidity_6')
white_wine_6['volatile acidity'].hist(range=[0.1,0.75])

subplot(4, 2, 5)
plt.title('Volatile Acidity_5')
white_wine_5['volatile acidity'].hist(range=[0.1,0.75])

subplot(4, 2, 6)
plt.title('Volatile Acidity_4')
white_wine_4['volatile acidity'].hist(range=[0.1,0.75])

subplot(4, 2, 7)
plt.title('Volatile Acidity_3')
white_wine_3['volatile acidity'].hist(range=[0.1,0.75])

plt.tight_layout()
# Out:
# Volatile Acidity

# %% [markdown]
# We see that higher acetic acid (volatile acidity > 0.5) correlates with lower quality wine (3,4,5).

# %%
#Build frequency histograms for each rating of each feature
fig, axes = plt.subplots(nrows=4, ncols=2)

print('Citric Acid')

subplot(4, 2, 1)
plt.title('Citric Acid_9')
white_wine_9['citric acid'].hist(range=[0.1,0.75])

subplot(4, 2, 2)
plt.title('Citric Acid_8')
white_wine_8['citric acid'].hist(range=[0.1,0.75])

subplot(4, 2, 3)
plt.title('Citric Acid_7')
white_wine_7['citric acid'].hist(range=[0.1,0.75])

subplot(4, 2, 4)
plt.title('Citric Acid_6')
white_wine_6['citric acid'].hist(range=[0.1,0.75])

subplot(4, 2, 5)
plt.title('Citric Acid_5')
white_wine_5['citric acid'].hist(range=[0.1,0.75])

subplot(4, 2, 6)
plt.title('Citric Acid_4')
white_wine_4['citric acid'].hist(range=[0.1,0.75])

subplot(4, 2, 7)
plt.title('Citric Acid_3')
white_wine_3['citric acid'].hist(range=[0.1,0.75])


plt.tight_layout()
# Out:
# Citric Acid

# %% [markdown]
# We see that there is a correlation of low quality wine (4,5) to citric acid levels above 0.6 or below 0.2.

# %%
#Build frequency histograms for each rating of each feature
fig, axes = plt.subplots(nrows=4, ncols=2)

print('Residual Sugar')

subplot(4, 2, 1)
plt.title('Residual Sugar_9')
white_wine_9['residual sugar'].hist(range=[0,12])

subplot(4, 2, 2)
plt.title('Residual Sugar_8')
white_wine_8['residual sugar'].hist(range=[0,12])

subplot(4, 2, 3)
plt.title('Residual Sugar_7')
white_wine_7['residual sugar'].hist(range=[0,12])

subplot(4, 2, 4)
plt.title('Residual Sugar_6')
white_wine_6['residual sugar'].hist(range=[0,12])

subplot(4, 2, 5)
plt.title('Residual Sugar_5')
white_wine_5['residual sugar'].hist(range=[0,12])

subplot(4, 2, 6)
plt.title('Residual Sugar_4')
white_wine_4['residual sugar'].hist(range=[0,12])

subplot(4, 2, 7)
plt.title('Residual Sugar_3')
white_wine_3['residual sugar'].hist(range=[0,12])


plt.tight_layout()
# Out:
# Residual Sugar

# %% [markdown]
# There seems to be no correlation of residual sugar to quality of wine.

# %%
#Build frequency histograms for each rating of each feature
fig, axes = plt.subplots(nrows=4, ncols=2)

print('Chlorides')

subplot(4, 2, 1)
plt.title('Chlorides_9')
white_wine_9['chlorides'].hist(range=[0.02,0.1])

subplot(4, 2, 2)
plt.title('Chlorides_8')
white_wine_8['chlorides'].hist(range=[0.02,0.1])

subplot(4, 2, 3)
plt.title('Chlorides_7')
white_wine_7['chlorides'].hist(range=[0.02,0.1])

subplot(4, 2, 4)
plt.title('Chlorides_6')
white_wine_6['chlorides'].hist(range=[0.02,0.1])

subplot(4, 2, 5)
plt.title('Chlorides_5')
white_wine_5['chlorides'].hist(range=[0.02,0.1])

subplot(4, 2, 6)
plt.title('Chlorides_4')
white_wine_4['chlorides'].hist(range=[0.02,0.1])

subplot(4, 2, 7)
plt.title('Chlorides_3')
white_wine_3['chlorides'].hist(range=[0.02,0.1])


plt.tight_layout()
# Out:
# Chlorides

# %% [markdown]
# There seems to be a correlation of high quality wine (7,8,9) to low chloride content and vice versa.

# %%
#Build frequency histograms for each rating of each feature
fig, axes = plt.subplots(nrows=4, ncols=2)

print('Free Sulfur Dioxide')

subplot(4, 2, 1)
plt.title('Free Sulfur Dioxide_9')
white_wine_9['fixed acidity'].hist(range=[4,10])

subplot(4, 2, 2)
plt.title('Free Sulfur Dioxide_8')
white_wine_8['fixed acidity'].hist(range=[4,10])

subplot(4, 2, 3)
plt.title('Free Sulfur Dioxide_7')
white_wine_7['fixed acidity'].hist(range=[4,10])

subplot(4, 2, 4)
plt.title('Free Sulfur Dioxide_6')
white_wine_6['fixed acidity'].hist(range=[4,10])

subplot(4, 2, 5)
plt.title('Free Sulfur Dioxide_5')
white_wine_5['fixed acidity'].hist(range=[4,10])

subplot(4, 2, 6)
plt.title('Free Sulfur Dioxide_4')
white_wine_4['fixed acidity'].hist(range=[4,10])

subplot(4, 2, 7)
plt.title('Free Sulfur Dioxide_3')
white_wine_3['fixed acidity'].hist(range=[4,10])


plt.tight_layout()
# Out:
# Free Sulfur Dioxide

# %% [markdown]
# Lower 'free sulfur dioxide' content correlates with lower quality wine and vice versa.

# %%
#Build frequency histograms for each rating of each feature
fig, axes = plt.subplots(nrows=4, ncols=2)

print('Total Sulfur Dioxide')

subplot(4, 2, 1)
plt.title('Total Sulfur Dioxide_9')
white_wine_9['total sulfur dioxide'].hist(range=[0,300])

subplot(4, 2, 2)
plt.title('Total Sulfur Dioxide_8')
white_wine_8['total sulfur dioxide'].hist(range=[0,300])

subplot(4, 2, 3)
plt.title('Total Sulfur Dioxide_7')
white_wine_7['total sulfur dioxide'].hist(range=[0,300])

subplot(4, 2, 4)
plt.title('Total Sulfur Dioxide_6')
white_wine_6['total sulfur dioxide'].hist(range=[0,300])

subplot(4, 2, 5)
plt.title('Total Sulfur Dioxide_5')
white_wine_5['total sulfur dioxide'].hist(range=[0,300])

subplot(4, 2, 6)
plt.title('Total Sulfur Dioxide_4')
white_wine_4['total sulfur dioxide'].hist(range=[0,300])

subplot(4, 2, 7)
plt.title('Total Sulfur Dioxide_3')
white_wine_3['total sulfur dioxide'].hist(range=[0,300])


plt.tight_layout()
# Out:
# Total Sulfur Dioxide

# %% [markdown]
# Where 'total sulfur dioxide' < ~75, we see a high chance of low quality wine.

# %%
#Build frequency histograms for each rating of each feature
fig, axes = plt.subplots(nrows=4, ncols=2)

print('Density')

subplot(4, 2, 1)
plt.title('Density_9')
white_wine_9['fixed acidity'].hist(range=[3,10])

subplot(4, 2, 2)
plt.title('Density_8')
white_wine_8['fixed acidity'].hist(range=[3,10])

subplot(4, 2, 3)
plt.title('Density_7')
white_wine_7['fixed acidity'].hist(range=[3,10])

subplot(4, 2, 4)
plt.title('Density_6')
white_wine_6['fixed acidity'].hist(range=[3,10])

subplot(4, 2, 5)
plt.title('Density_5')
white_wine_5['fixed acidity'].hist(range=[3,10])

subplot(4, 2, 6)
plt.title('Density_4')
white_wine_4['fixed acidity'].hist(range=[3,10])

subplot(4, 2, 7)
plt.title('Density_3')
white_wine_3['fixed acidity'].hist(range=[3,10])


plt.tight_layout()
# Out:
# Density

# %% [markdown]
# We see that density greater than 9 correlates with lower quality wine.

# %%
#Build frequency histograms for each rating of each feature
fig, axes = plt.subplots(nrows=4, ncols=2)

print('pH')

subplot(4, 2, 1)
plt.title('pH_9')
white_wine_9['pH'].hist(range=[2.8,3.5])

subplot(4, 2, 2)
plt.title('pH_8')
white_wine_8['pH'].hist(range=[2.8,3.5])

subplot(4, 2, 3)
plt.title('pH_7')
white_wine_7['pH'].hist(range=[2.8,3.5])

subplot(4, 2, 4)
plt.title('pH_6')
white_wine_6['pH'].hist(range=[2.8,3.5])

subplot(4, 2, 5)
plt.title('pH_5')
white_wine_5['pH'].hist(range=[2.8,3.5])

subplot(4, 2, 6)
plt.title('pH_4')
white_wine_4['pH'].hist(range=[2.8,3.5])

subplot(4, 2, 7)
plt.title('pH_3')
white_wine_3['pH'].hist(range=[2.8,3.5])


plt.tight_layout()
# Out:
# pH

# %% [markdown]
# The higher the pH the better the chance it will be a high quality wine.

# %%
#Build frequency histograms for each rating of each feature
fig, axes = plt.subplots(nrows=4, ncols=2)

print('Sulphates')

subplot(4, 2, 1)
plt.title('Sulphates_9')
white_wine_9['sulphates'].hist(range=[0.25,0.75])

subplot(4, 2, 2)
plt.title('Sulphates_8')
white_wine_8['sulphates'].hist(range=[0.25,0.75])

subplot(4, 2, 3)
plt.title('Sulphates_7')
white_wine_7['sulphates'].hist(range=[0.25,0.75])

subplot(4, 2, 4)
plt.title('Sulphates_6')
white_wine_6['sulphates'].hist(range=[0.25,0.75])

subplot(4, 2, 5)
plt.title('Sulphates_5')
white_wine_5['sulphates'].hist(range=[0.25,0.75])

subplot(4, 2, 6)
plt.title('Sulphates_4')
white_wine_4['sulphates'].hist(range=[0.25,0.75])

subplot(4, 2, 7)
plt.title('Sulphates_3')
white_wine_3['sulphates'].hist(range=[0.25,0.75])


plt.tight_layout()
# Out:
# Sulphates

# %% [markdown]
# I see no correlation here.

# %%
#Build frequency histograms for each rating of each feature
fig, axes = plt.subplots(nrows=4, ncols=2)

print('Alcohol')

subplot(4, 2, 1)
plt.title('Alcohol_9')
white_wine_9['alcohol'].hist(range=[8,13])

subplot(4, 2, 2)
plt.title('Alcohol_8')
white_wine_8['alcohol'].hist(range=[8,13])

subplot(4, 2, 3)
plt.title('Alcohol_7')
white_wine_7['alcohol'].hist(range=[8,13])

subplot(4, 2, 4)
plt.title('Alcohol_6')
white_wine_6['alcohol'].hist(range=[8,13])

subplot(4, 2, 5)
plt.title('Alcohol_5')
white_wine_5['alcohol'].hist(range=[8,13])

subplot(4, 2, 6)
plt.title('Alcohol_4')
white_wine_4['alcohol'].hist(range=[8,13])

subplot(4, 2, 7)
plt.title('Alcohol_3')
white_wine_3['alcohol'].hist(range=[8,13])


plt.tight_layout()
# Out:
# Alcohol

# %% [markdown]
# A higher the alchohol content correlates to a higher quality rating and vice versa.

# %%
#Analyze mean values of features for each quality rating
mean_values = white_wine.groupby('quality').agg(np.mean)
print (mean_values)
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3             7.600000          0.333250     0.336000        6.392500
# 4             7.129448          0.381227     0.304233        4.628221
# 5             6.933974          0.302011     0.337653        7.334969
# 6             6.837671          0.260564     0.338025        6.441606
# 7             6.734716          0.262767     0.325625        5.186477
# 8             6.657143          0.277400     0.326514        5.671429
# 9             7.420000          0.298000     0.386000        4.120000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 3         0.054300            53.325000            170.600000  0.994884
# 4         0.050098            23.358896            125.279141  0.994277
# 5         0.051546            36.432052            150.904598  0.995263
# 6         0.045217            35.650591            137.047316  0.993961
# ...

# %%
print('Lower residual sugar seems to correlate to higher quality wine. Histogram analysis found no correlation.')
print('Lower chloride content correlates with higher quality wine. Confirms the histogram analysis.')
print('Lower total sulfur dioxide correlates with higher quality wine. Histogram analysis found a similar correlation.')
print('Lower density correlates to a higher quality wine. Histogram analysis found a different correlation.')
print('Higher pH correlates to a higher quality wine. Histrogram analysis confirms this.')
print('Higher alcohol content correlates with a higher quality wine. Histrogram analysis confirms this.')
# Out:
# Lower residual sugar seems to correlate to higher quality wine. Histogram analysis found no correlation.
# Lower chloride content correlates with higher quality wine. Confirms the histogram analysis.
# Lower total sulfur dioxide correlates with higher quality wine. Histogram analysis found a different correlation.
# Lower density correlates to a higher quality wine. Histogram analysis found a different correlation.
# Higher pH correlates to a higher quality wine. Histrogram analysis confirms this.
# Higher alcohol content correlates with a higher quality wine. Histrogram analysis confirms this.

# %%
range_values = white_wine.groupby('quality').agg(['min', 'max'])
print(range_values.loc[:, 'fixed acidity':'total sulfur dioxide'])
# Out:
#         fixed acidity       volatile acidity        citric acid        \
#                   min   max              min    max         min   max
# quality
# 3                 4.2  11.8             0.17  0.640        0.21  0.47
# 4                 4.8  10.2             0.11  1.100        0.00  0.88
# 5                 4.5  10.3             0.10  0.905        0.00  1.00
# 6                 3.8  14.2             0.08  0.965        0.00  1.66
# 7                 4.2   9.2             0.08  0.760        0.01  0.74
# 8                 3.9   8.2             0.12  0.660        0.04  0.74
# 9                 6.6   9.1             0.24  0.360        0.29  0.49
#
#         residual sugar        chlorides        free sulfur dioxide         \
#                    min    max       min    max                 min    max
# quality
# 3                  0.7  16.20     0.022  0.244                 5.0  289.0
# 4                  0.7  17.55     0.013  0.290                 3.0  138.5
# ...

# %%
print('fixed acidity greater than 9.2 translates to lower quality wine.')
print("volatile acidity greater than 0.760 translates to lower quality wine. This complements the histograms' findings.")
print('residual sugar greater than 19.25 or less than 0.8 translates to lower quality wine.')
print('chloride levels above 0.135 translates to lower quality wine.')
print('free sulfur dioxide content that is above 108 or below 5 translates to lower quality wine. histogram found different.')
print('total sulfur dioxide above 229 and below 34 translates to lower quality wine. Histogram found slightly different.')
# Out:
# fixed acidity greater than 9.2 translates to lower quality wine.
# volatile acidity greater than 0.760 translates to lower quality wine. This complements the histograms' findings.
# residual sugar greater than 19.25 or less than 0.8 translates to lower quality wine.
# chloride levels above 0.135 translates to lower quality wine.
# free sulfur dioxide content that is above 108 or below 5 translates to lower quality wine. histogram found different.
# total sulfur dioxide above 229 and below 34 translates to lower quality wine. Histogram found slightly different.

# %%
print(range_values.loc[:, 'total sulfur dioxide': ])
# Out:
#         total sulfur dioxide         density             pH       sulphates  \
#                          min    max      min      max   min   max       min
# quality
# 3                       19.0  440.0  0.99110  1.00010  2.87  3.55      0.28
# 4                       10.0  272.0  0.98920  1.00040  2.83  3.72      0.25
# 5                        9.0  344.0  0.98722  1.00241  2.79  3.79      0.27
# 6                       18.0  294.0  0.98758  1.03898  2.72  3.81      0.23
# 7                       34.0  229.0  0.98711  1.00040  2.84  3.82      0.22
# 8                       59.0  212.5  0.98713  1.00060  2.94  3.59      0.25
# 9                       85.0  139.0  0.98965  0.99700  3.20  3.41      0.36
#
#               alcohol
#           max     min   max
# quality
# 3        0.74     8.0  12.6
# 4        0.87     8.4  13.5
# 5        0.88     8.0  13.6
# 6        1.06     8.5  14.0
# 7        1.08     8.6  14.2
# 8        0.95     8.5  14.0
# 9        0.61    10.4  12.9

# %%
print('alcohol less than 8.5 correlates to lower quality wine.')
# Out:
# alcohol less than 8.5 correlates to lower quality wine.

# %%
median_values = white_wine.groupby('quality').median()
print(median_values)
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3                  7.3              0.26        0.345            4.60
# 4                  6.9              0.32        0.290            2.50
# 5                  6.8              0.28        0.320            7.00
# 6                  6.8              0.25        0.320            5.30
# 7                  6.7              0.25        0.310            3.65
# 8                  6.8              0.26        0.320            4.30
# 9                  7.1              0.27        0.360            2.20
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 3            0.041                 33.5                 159.5  0.994425
# 4            0.046                 18.0                 117.0  0.994100
# 5            0.047                 35.0                 151.0  0.995300
# 6            0.043                 34.0                 132.0  0.993660
# ...

# %%
print('Lower chloride content correlates with higher quality wine. Confirms the histogram analysis.')
print('Lower total sulfur dioxide correlates with higher quality wine. Histogram analysis found a similar correlation.')
print('Lower density correlates to a higher quality wine. Histogram analysis found a different correlation.')
print('Higher pH correlates to a higher quality wine. Histrogram analysis confirms this.')
print('Higher alcohol content correlates with a higher quality wine. Histrogram analysis confirms this.')
# Out:
# Lower chloride content correlates with higher quality wine. Confirms the histogram analysis.
# Lower total sulfur dioxide correlates with higher quality wine. Histogram analysis found a similar correlation.
# Lower density correlates to a higher quality wine. Histogram analysis found a different correlation.
# Higher pH correlates to a higher quality wine. Histrogram analysis confirms this.
# Higher alcohol content correlates with a higher quality wine. Histrogram analysis confirms this.
