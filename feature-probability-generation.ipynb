# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pylab import *
import sklearn as sklearn
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.metrics import confusion_matrix

# %%
# %run distribution-generator.ipynb
# Out:
# distribution-generator.ipynb:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   "C:\\Users\\ramka\\Anaconda3\\lib\\site-packages\\ipykernel_launcher.py:14: SettingWithCopyWarning: \n",
# distribution-generator.ipynb:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   "A value is trying to be set on a copy of a slice from a DataFrame.\n",
# distribution-generator.ipynb:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#-----------------------------------------High Quality Training  Wine Data--------------------------------------------------------

#Alcohol probability
min_value = np.amin(high_quality_alcohol_dist)
max_value = np.amax(high_quality_alcohol_dist)
interval_step = (max_value - min_value)/20
alcohol_prob = np.empty(4898)
index_count = 0

for index, row in white_wine_new.iterrows():
    count = 0
    interval_low = row['alcohol'] - interval_step
    interval_high = row['alcohol'] + interval_step
  
    for i in high_quality_alcohol_dist:
        if i >= interval_low and i <= interval_high:
            count += 1
    alcohol_prob[index_count] = count/10000
    index_count += 1

white_wine_new['alcohol_prob_high'] = alcohol_prob


#Density Probability
min_value = np.amin(high_quality_density_dist)
max_value = np.amax(high_quality_density_dist)
interval_step = (max_value - min_value)/20
density_prob = np.empty(4898)
index_count = 0

for index, row in white_wine_new.iterrows():
    count = 0
    interval_low = row['density'] - interval_step
    interval_high = row['density'] + interval_step
  
    for i in high_quality_density_dist:
        if i >= interval_low and i <= interval_high:
            count += 1
    density_prob[index_count] = count/10000
    index_count += 1

white_wine_new['density_prob_high'] = density_prob


#Total sulfur dioxide probability
min_value = np.amin(high_quality_total_sulfur_dioxide_dist)
max_value = np.amax(high_quality_total_sulfur_dioxide_dist)
interval_step = (max_value - min_value)/20
total_sulfur_dioxide_prob = np.empty(4898)
index_count = 0

for index, row in white_wine_new.iterrows():
    count = 0
    interval_low = row['total sulfur dioxide'] - interval_step
    interval_high = row['total sulfur dioxide'] + interval_step
  
    for i in high_quality_total_sulfur_dioxide_dist:
        if i >= interval_low and i <= interval_high:
            count += 1
    total_sulfur_dioxide_prob[index_count] = count/10000
    index_count += 1

white_wine_new['total_sulfur_dioxide_prob_high'] = total_sulfur_dioxide_prob


#Free Sulfur Dioxide Probability
min_value = np.amin(high_quality_free_sulfur_dioxide_dist)
max_value = np.amax(high_quality_free_sulfur_dioxide_dist)
interval_step = (max_value - min_value)/20
free_sulfur_dioxide_prob = np.empty(4898)
index_count = 0

for index, row in white_wine_new.iterrows():
    count = 0
    interval_low = row['free sulfur dioxide'] - interval_step
    interval_high = row['free sulfur dioxide'] + interval_step
  
    for i in high_quality_free_sulfur_dioxide_dist:
        if i >= interval_low and i <= interval_high:
            count += 1
    free_sulfur_dioxide_prob[index_count] = count/10000
    index_count += 1

white_wine_new['free_sulfur_dioxide_prob_high'] = free_sulfur_dioxide_prob


#Chlorides probability
min_value = np.amin(high_quality_chloride_dist)
max_value = np.amax(high_quality_chloride_dist)
interval_step = (max_value - min_value)/20
chlorides_prob = np.empty(4898)
index_count = 0

for index, row in white_wine_new.iterrows():
    count = 0
    interval_low = row['chlorides'] - interval_step
    interval_high = row['chlorides'] + interval_step
  
    for i in high_quality_chloride_dist:
        if i >= interval_low and i <= interval_high:
            count += 1
    chlorides_prob[index_count] = count/10000
    index_count += 1

white_wine_new['chlorides_prob_high'] = chlorides_prob


#Residual Sugar Probability
min_value = np.amin(high_quality_residual_sugar_dist)
max_value = np.amax(high_quality_residual_sugar_dist)
interval_step = (max_value - min_value)/20
residual_sugar_prob = np.empty(4898)
index_count = 0

for index, row in white_wine_new.iterrows():
    count = 0
    interval_low = row['residual sugar'] - interval_step
    interval_high = row['residual sugar'] + interval_step
  
    for i in high_quality_residual_sugar_dist:
        if i >= interval_low and i <= interval_high:
            count += 1
    residual_sugar_prob[index_count] = count/10000
    index_count += 1

white_wine_new['residual_sugar_prob_high'] = residual_sugar_prob


#Citric Acid Probability
min_value = np.amin(high_quality_citric_acid_dist)
max_value = np.amax(high_quality_citric_acid_dist)
interval_step = (max_value - min_value)/20
citric_acid_prob = np.empty(4898)
index_count = 0

for index, row in white_wine_new.iterrows():
    count = 0
    interval_low = row['citric acid'] - interval_step
    interval_high = row['citric acid'] + interval_step
  
    for i in high_quality_citric_acid_dist:
        if i >= interval_low and i <= interval_high:
            count += 1
    citric_acid_prob[index_count] = count/10000
    index_count += 1

white_wine_new['citric_acid_prob_high'] = citric_acid_prob


#Volatile Acidity Probability
min_value = np.amin(high_quality_volatile_acidity_dist)
max_value = np.amax(high_quality_volatile_acidity_dist)
interval_step = (max_value - min_value)/20
volatile_acidity_prob = np.empty(4898)
index_count = 0

for index, row in white_wine_new.iterrows():
    count = 0
    interval_low = row['volatile acidity'] - interval_step
    interval_high = row['volatile acidity'] + interval_step
  
    for i in high_quality_volatile_acidity_dist:
        if i >= interval_low and i <= interval_high:
            count += 1
    volatile_acidity_prob[index_count] = count/10000
    index_count += 1

white_wine_new['volatile_acidity_prob_high'] = volatile_acidity_prob

#Fixed Acidity Probability
min_value = np.amin(high_quality_fixed_acidity_dist)
max_value = np.amax(high_quality_fixed_acidity_dist)
interval_step = (max_value - min_value)/20
fixed_acidity_prob = np.empty(4898)
index_count = 0

for index, row in white_wine_new.iterrows():
    count = 0
    interval_low = row['fixed acidity'] - interval_step
    interval_high = row['fixed acidity'] + interval_step
  
    for i in high_quality_fixed_acidity_dist:
        if i >= interval_low and i <= interval_high:
            count += 1
    fixed_acidity_prob[index_count] = count/10000
    index_count += 1

white_wine_new['fixed_acidity_prob_high'] = fixed_acidity_prob


#Sulphates Probability
min_value = np.amin(high_quality_sulphates_dist)
max_value = np.amax(high_quality_sulphates_dist)
interval_step = (max_value - min_value)/20
sulphates_prob = np.empty(4898)
index_count = 0

for index, row in white_wine_new.iterrows():
    count = 0
    interval_low = row['sulphates'] - interval_step
    interval_high = row['sulphates'] + interval_step
  
    for i in high_quality_sulphates_dist:
        if i >= interval_low and i <= interval_high:
            count += 1
    sulphates_prob[index_count] = count/10000
    index_count += 1

white_wine_new['sulphates_prob_high'] = sulphates_prob


#pH probability
min_value = np.amin(high_quality_pH_dist)
max_value = np.amax(high_quality_pH_dist)
interval_step = (max_value - min_value)/20
pH_prob = np.empty(4898)
index_count = 0

for index, row in white_wine_new.iterrows():
    count = 0
    interval_low = row['pH'] - interval_step
    interval_high = row['pH'] + interval_step
  
    for i in high_quality_pH_dist:
        if i >= interval_low and i <= interval_high:
            count += 1
    pH_prob[index_count] = count/10000
    index_count += 1

white_wine_new['pH_prob_high'] = pH_prob

# %%
#-------------------------------------Mid Quality Training Wine Data--------------------------------------------------------

#Alcohol probability
min_value = np.amin(mid_quality_alcohol_dist)
max_value = np.amax(mid_quality_alcohol_dist)
interval_step = (max_value - min_value)/20
alcohol_prob = np.empty(4898)
index_count = 0

for index, row in white_wine_new.iterrows():
    count = 0
    interval_low = row['alcohol'] - interval_step
    interval_high = row['alcohol'] + interval_step
  
    for i in mid_quality_alcohol_dist:
        if i >= interval_low and i <= interval_high:
            count += 1
    alcohol_prob[index_count] = count/10000
    index_count += 1

white_wine_new['alcohol_prob_mid'] = alcohol_prob


#Density Probability
min_value = np.amin(mid_quality_density_dist)
max_value = np.amax(mid_quality_density_dist)
interval_step = (max_value - min_value)/20
density_prob = np.empty(4898)
index_count = 0

for index, row in white_wine_new.iterrows():
    count = 0
    interval_low = row['density'] - interval_step
    interval_high = row['density'] + interval_step
  
    for i in mid_quality_density_dist:
        if i >= interval_low and i <= interval_high:
            count += 1
    density_prob[index_count] = count/10000
    index_count += 1

white_wine_new['density_prob_mid'] = density_prob


#Total sulfur dioxide probability
min_value = np.amin(mid_quality_total_sulfur_dioxide_dist)
max_value = np.amax(mid_quality_total_sulfur_dioxide_dist)
interval_step = (max_value - min_value)/20
total_sulfur_dioxide_prob = np.empty(4898)
index_count = 0

for index, row in white_wine_new.iterrows():
    count = 0
    interval_low = row['total sulfur dioxide'] - interval_step
    interval_high = row['total sulfur dioxide'] + interval_step
  
    for i in mid_quality_total_sulfur_dioxide_dist:
        if i >= interval_low and i <= interval_high:
            count += 1
    total_sulfur_dioxide_prob[index_count] = count/10000
    index_count += 1

white_wine_new['total_sulfur_dioxide_prob_mid'] = total_sulfur_dioxide_prob


#Free Sulfur Dioxide Probability
min_value = np.amin(mid_quality_free_sulfur_dioxide_dist)
max_value = np.amax(mid_quality_free_sulfur_dioxide_dist)
interval_step = (max_value - min_value)/20
free_sulfur_dioxide_prob = np.empty(4898)
index_count = 0

for index, row in white_wine_new.iterrows():
    count = 0
    interval_low = row['free sulfur dioxide'] - interval_step
    interval_high = row['free sulfur dioxide'] + interval_step
  
    for i in mid_quality_free_sulfur_dioxide_dist:
        if i >= interval_low and i <= interval_high:
            count += 1
    free_sulfur_dioxide_prob[index_count] = count/10000
    index_count += 1

white_wine_new['free_sulfur_dioxide_prob_mid'] = free_sulfur_dioxide_prob


#Chlorides probability
min_value = np.amin(mid_quality_chloride_dist)
max_value = np.amax(mid_quality_chloride_dist)
interval_step = (max_value - min_value)/20
chlorides_prob = np.empty(4898)
index_count = 0

for index, row in white_wine_new.iterrows():
    count = 0
    interval_low = row['chlorides'] - interval_step
    interval_high = row['chlorides'] + interval_step
  
    for i in mid_quality_chloride_dist:
        if i >= interval_low and i <= interval_high:
            count += 1
    chlorides_prob[index_count] = count/10000
    index_count += 1

white_wine_new['chlorides_prob_mid'] = chlorides_prob


#Residual Sugar Probability
min_value = np.amin(mid_quality_residual_sugar_dist)
max_value = np.amax(mid_quality_residual_sugar_dist)
interval_step = (max_value - min_value)/20
residual_sugar_prob = np.empty(4898)
index_count = 0

for index, row in white_wine_new.iterrows():
    count = 0
    interval_low = row['residual sugar'] - interval_step
    interval_high = row['residual sugar'] + interval_step
  
    for i in mid_quality_residual_sugar_dist:
        if i >= interval_low and i <= interval_high:
            count += 1
    residual_sugar_prob[index_count] = count/10000
    index_count += 1

white_wine_new['residual_sugar_prob_mid'] = residual_sugar_prob


#Citric Acid Probability
min_value = np.amin(mid_quality_citric_acid_dist)
max_value = np.amax(mid_quality_citric_acid_dist)
interval_step = (max_value - min_value)/20
citric_acid_prob = np.empty(4898)
index_count = 0

for index, row in white_wine_new.iterrows():
    count = 0
    interval_low = row['citric acid'] - interval_step
    interval_high = row['citric acid'] + interval_step
  
    for i in mid_quality_citric_acid_dist:
        if i >= interval_low and i <= interval_high:
            count += 1
    citric_acid_prob[index_count] = count/10000
    index_count += 1

white_wine_new['citric_acid_prob_mid'] = citric_acid_prob


#Volatile Acidity Probability
min_value = np.amin(mid_quality_volatile_acidity_dist)
max_value = np.amax(mid_quality_volatile_acidity_dist)
interval_step = (max_value - min_value)/20
volatile_acidity_prob = np.empty(4898)
index_count = 0

for index, row in white_wine_new.iterrows():
    count = 0
    interval_low = row['volatile acidity'] - interval_step
    interval_high = row['volatile acidity'] + interval_step
  
    for i in mid_quality_volatile_acidity_dist:
        if i >= interval_low and i <= interval_high:
            count += 1
    volatile_acidity_prob[index_count] = count/10000
    index_count += 1

white_wine_new['volatile_acidity_prob_mid'] = volatile_acidity_prob

#Fixed Acidity Probability
min_value = np.amin(mid_quality_fixed_acidity_dist)
max_value = np.amax(mid_quality_fixed_acidity_dist)
interval_step = (max_value - min_value)/20
fixed_acidity_prob = np.empty(4898)
index_count = 0

for index, row in white_wine_new.iterrows():
    count = 0
    interval_low = row['fixed acidity'] - interval_step
    interval_high = row['fixed acidity'] + interval_step
  
    for i in mid_quality_fixed_acidity_dist:
        if i >= interval_low and i <= interval_high:
            count += 1
    fixed_acidity_prob[index_count] = count/10000
    index_count += 1

white_wine_new['fixed_acidity_prob_mid'] = fixed_acidity_prob


#Sulphates Probability
min_value = np.amin(mid_quality_sulphates_dist)
max_value = np.amax(mid_quality_sulphates_dist)
interval_step = (max_value - min_value)/20
sulphates_prob = np.empty(4898)
index_count = 0

for index, row in white_wine_new.iterrows():
    count = 0
    interval_low = row['sulphates'] - interval_step
    interval_high = row['sulphates'] + interval_step
  
    for i in mid_quality_sulphates_dist:
        if i >= interval_low and i <= interval_high:
            count += 1
    sulphates_prob[index_count] = count/10000
    index_count += 1

white_wine_new['sulphates_prob_mid'] = sulphates_prob


#pH probability
min_value = np.amin(mid_quality_pH_dist)
max_value = np.amax(mid_quality_pH_dist)
interval_step = (max_value - min_value)/20
pH_prob = np.empty(4898)
index_count = 0

for index, row in white_wine_new.iterrows():
    count = 0
    interval_low = row['pH'] - interval_step
    interval_high = row['pH'] + interval_step
  
    for i in mid_quality_pH_dist:
        if i >= interval_low and i <= interval_high:
            count += 1
    pH_prob[index_count] = count/10000
    index_count += 1

white_wine_new['pH_prob_mid'] = pH_prob

# %%
#-------------------------------------low Quality Training Wine Data--------------------------------------------------------

#Alcohol probability
min_value = np.amin(low_quality_alcohol_dist)
max_value = np.amax(low_quality_alcohol_dist)
interval_step = (max_value - min_value)/20
alcohol_prob = np.empty(4898)
index_count = 0

for index, row in white_wine_new.iterrows():
    count = 0
    interval_low = row['alcohol'] - interval_step
    interval_high = row['alcohol'] + interval_step
  
    for i in low_quality_alcohol_dist:
        if i >= interval_low and i <= interval_high:
            count += 1
    alcohol_prob[index_count] = count/10000
    index_count += 1

white_wine_new['alcohol_prob_low'] = alcohol_prob


#Density Probability
min_value = np.amin(low_quality_density_dist)
max_value = np.amax(low_quality_density_dist)
interval_step = (max_value - min_value)/20
density_prob = np.empty(4898)
index_count = 0

for index, row in white_wine_new.iterrows():
    count = 0
    interval_low = row['density'] - interval_step
    interval_high = row['density'] + interval_step
  
    for i in low_quality_density_dist:
        if i >= interval_low and i <= interval_high:
            count += 1
    density_prob[index_count] = count/10000
    index_count += 1

white_wine_new['density_prob_low'] = density_prob


#Total sulfur dioxide probability
min_value = np.amin(low_quality_total_sulfur_dioxide_dist)
max_value = np.amax(low_quality_total_sulfur_dioxide_dist)
interval_step = (max_value - min_value)/20
total_sulfur_dioxide_prob = np.empty(4898)
index_count = 0

for index, row in white_wine_new.iterrows():
    count = 0
    interval_low = row['total sulfur dioxide'] - interval_step
    interval_high = row['total sulfur dioxide'] + interval_step
  
    for i in low_quality_total_sulfur_dioxide_dist:
        if i >= interval_low and i <= interval_high:
            count += 1
    total_sulfur_dioxide_prob[index_count] = count/10000
    index_count += 1

white_wine_new['total_sulfur_dioxide_prob_low'] = total_sulfur_dioxide_prob


#Free Sulfur Dioxide Probability
min_value = np.amin(low_quality_free_sulfur_dioxide_dist)
max_value = np.amax(low_quality_free_sulfur_dioxide_dist)
interval_step = (max_value - min_value)/20
free_sulfur_dioxide_prob = np.empty(4898)
index_count = 0

for index, row in white_wine_new.iterrows():
    count = 0
    interval_low = row['free sulfur dioxide'] - interval_step
    interval_high = row['free sulfur dioxide'] + interval_step
  
    for i in low_quality_free_sulfur_dioxide_dist:
        if i >= interval_low and i <= interval_high:
            count += 1
    free_sulfur_dioxide_prob[index_count] = count/10000
    index_count += 1

white_wine_new['free_sulfur_dioxide_prob_low'] = free_sulfur_dioxide_prob


#Chlorides probability
min_value = np.amin(low_quality_chloride_dist)
max_value = np.amax(low_quality_chloride_dist)
interval_step = (max_value - min_value)/20
chlorides_prob = np.empty(4898)
index_count = 0

for index, row in white_wine_new.iterrows():
    count = 0
    interval_low = row['chlorides'] - interval_step
    interval_high = row['chlorides'] + interval_step
  
    for i in low_quality_chloride_dist:
        if i >= interval_low and i <= interval_high:
            count += 1
    chlorides_prob[index_count] = count/10000
    index_count += 1

white_wine_new['chlorides_prob_low'] = chlorides_prob


#Residual Sugar Probability
min_value = np.amin(low_quality_residual_sugar_dist)
max_value = np.amax(low_quality_residual_sugar_dist)
interval_step = (max_value - min_value)/20
residual_sugar_prob = np.empty(4898)
index_count = 0

for index, row in white_wine_new.iterrows():
    count = 0
    interval_low = row['residual sugar'] - interval_step
    interval_high = row['residual sugar'] + interval_step
  
    for i in low_quality_residual_sugar_dist:
        if i >= interval_low and i <= interval_high:
            count += 1
    residual_sugar_prob[index_count] = count/10000
    index_count += 1

white_wine_new['residual_sugar_prob_low'] = residual_sugar_prob


#Citric Acid Probability
min_value = np.amin(low_quality_citric_acid_dist)
max_value = np.amax(low_quality_citric_acid_dist)
interval_step = (max_value - min_value)/20
citric_acid_prob = np.empty(4898)
index_count = 0

for index, row in white_wine_new.iterrows():
    count = 0
    interval_low = row['citric acid'] - interval_step
    interval_high = row['citric acid'] + interval_step
  
    for i in low_quality_citric_acid_dist:
        if i >= interval_low and i <= interval_high:
            count += 1
    citric_acid_prob[index_count] = count/10000
    index_count += 1

white_wine_new['citric_acid_prob_low'] = citric_acid_prob


#Volatile Acidity Probability
min_value = np.amin(low_quality_volatile_acidity_dist)
max_value = np.amax(low_quality_volatile_acidity_dist)
interval_step = (max_value - min_value)/20
volatile_acidity_prob = np.empty(4898)
index_count = 0

for index, row in white_wine_new.iterrows():
    count = 0
    interval_low = row['volatile acidity'] - interval_step
    interval_high = row['volatile acidity'] + interval_step
  
    for i in low_quality_volatile_acidity_dist:
        if i >= interval_low and i <= interval_high:
            count += 1
    volatile_acidity_prob[index_count] = count/10000
    index_count += 1

white_wine_new['volatile_acidity_prob_low'] = volatile_acidity_prob

#Fixed Acidity Probability
min_value = np.amin(low_quality_fixed_acidity_dist)
max_value = np.amax(low_quality_fixed_acidity_dist)
interval_step = (max_value - min_value)/20
fixed_acidity_prob = np.empty(4898)
index_count = 0

for index, row in white_wine_new.iterrows():
    count = 0
    interval_low = row['fixed acidity'] - interval_step
    interval_high = row['fixed acidity'] + interval_step
  
    for i in low_quality_fixed_acidity_dist:
        if i >= interval_low and i <= interval_high:
            count += 1
    fixed_acidity_prob[index_count] = count/10000
    index_count += 1

white_wine_new['fixed_acidity_prob_low'] = fixed_acidity_prob


#Sulphates Probability
min_value = np.amin(low_quality_sulphates_dist)
max_value = np.amax(low_quality_sulphates_dist)
interval_step = (max_value - min_value)/20
sulphates_prob = np.empty(4898)
index_count = 0

for index, row in white_wine_new.iterrows():
    count = 0
    interval_low = row['sulphates'] - interval_step
    interval_high = row['sulphates'] + interval_step
  
    for i in low_quality_sulphates_dist:
        if i >= interval_low and i <= interval_high:
            count += 1
    sulphates_prob[index_count] = count/10000
    index_count += 1

white_wine_new['sulphates_prob_low'] = sulphates_prob


#pH probability
min_value = np.amin(low_quality_pH_dist)
max_value = np.amax(low_quality_pH_dist)
interval_step = (max_value - min_value)/20
pH_prob = np.empty(4898)
index_count = 0

for index, row in white_wine_new.iterrows():
    count = 0
    interval_low = row['pH'] - interval_step
    interval_high = row['pH'] + interval_step
  
    for i in low_quality_pH_dist:
        if i >= interval_low and i <= interval_high:
            count += 1
    pH_prob[index_count] = count/10000
    index_count += 1

white_wine_new['pH_prob_low'] = pH_prob

# %%
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 13              6.6             0.160         0.40            1.50      0.044
# 15              6.6             0.170         0.38            1.50      0.032
# 17              6.2             0.660         0.48            1.20      0.029
# 20              6.2             0.660         0.48            1.20      0.029
# 21              6.4             0.310         0.38            2.90      0.038
# 22              6.8             0.260         0.42            1.70      0.049
# 29              7.2             0.320         0.36            2.00      0.033
# 45              7.4             0.180         0.31            1.40      0.058
# 51              6.6             0.250         0.29            1.10      0.068
# 52              6.2             0.160         0.33            1.10      0.057
# 66              6.4             0.260         0.24            6.40      0.040
# ...
